# %%
x=int(input("Nhap vao so nguyen x: "))
s=(1+x+x**3/3+x**5/5)
s2=(1+x+(x**3)/3+(x**5)/5)
print(type(s))
print("1 + %d + %d^3/3 + %d^5/5= %.2f"%(x,x,x,s))
print("1 + %d + %d^3/3 + %d^5/5= %.2f"%(x,x,x,s2))

# %%
'''
Fundamentals of Python K254
Bài tập 3.2: Toán tử số học

Vinh Tran
08:08
Học viên sử dụng file đính kèm (3_2.py) và thực hiện:
1. Điền vào file giá trị biến result theo suy đoán
2. Cho chạy chương trình và quan sát biến result, giải thích sự khác biệt (nếu có) với kết quả mình đã làm ở bước 1.

3_2.py
Văn bản
Nhận xét của lớp học
Bài tập 3.2: Toán tử số học

Created on Feb 2, 2017

Trung Tam Tin Hoc - DH KHTN

'''
# tinh gia tri 
result = 1 + 2
print('result =', result)
# result = 3

original_result = result
result = result - 1
print('result =', result)
# result = 2

original_result = result
result = result * 2
original_result = result
print('result =', result)
# result = 4

result = result ** 3
original_result = result
print('result =', result)
# result = 64

result = result + 8
original_result = result
print('result =', result)
# result = 72

result = result % 7
original_result = result
print('result =', result)
# result = 2

result = result // 2
original_result = result
print('result =', result)
# result = 1

# %%
'''
Created on Feb 2, 2017

Trung Tam Tin Hoc - DH KHTN
'''
result = 5
print('result =', result)
# result =5

result -= 1
print('result =', result)
# result =4

result += 3
print('result =', result)
# result =7

result = - result
print('result =', result)
# result =-7

result = True
print('not result =', not result)
# not result =False

# %%
'''
Created on Feb 2, 2017

Trung Tam Tin Hoc - DH KHTN
'''
x = 10
y = 4
print('x = %d, y = %d'%(x,y))
equivelence = x==y
print('x==y is', equivelence)
# equivelence = False

equivelence = x!=y
print('x!=y is', equivelence)
# equivelence = True

equivelence = x>y
print('x>y is', equivelence)
# equivelence = True



x = 8
y = 9
print('x = %d, y = %d'%(x,y))
equivelence = x>=y
print('x>=y is', equivelence)
# equivelence = False

equivelence = x<y
print('x<y is', equivelence)
# equivelence = True

equivelence = x<=y
print('x<=y is', equivelence)
# equivelence =  True

# %%
'''
Created on Feb 2, 2017

Trung Tam Tin Hoc - DH KHTN
'''
x = 15
y = 12
print('Binary of x =', bin(x), ', Binary of y =', bin(y))
print('x & y =', bin(x & y))
print('x | y =', bin(x | y))
print('x ^ y =', bin(x ^ y))
print('~x =', bin(~x))
print('x << 2 =', bin(x << 2))
print('y >> 2 =', bin(y >> 2))

# %%
'''
Created on Feb 2, 2017

Trung Tam Tin Hoc - DH KHTN
'''
x = True
y = False
print('x and y :',x and y)
# x and y : False

print('x or y :',x or y)
# x or y : True

print('not x :',not x)
# not x :False

print('x is y :', x is y)
# x is y :False

print('x is not y :', x is not y)
# x is not y :True

# %%
m=int(input("Nhap so nguyen m co 3 chu so: "))
print("so dao cua %d la: %d"%(m,m//100+((m%100)//10)*10+(m%10)*100))

# %%
#Tim gia tri lon nhat
a=float(input("a= "))
b=float(input("b= "))
c=float(input("c= "))
d=float(input("d= "))
gtln=a
if gtln<b:
    gtln=b
if gtln<c:
    gtln=c
if gtln<d:
    gtln=d
print("Gia tri lon nhat = %.2f"%(gtln))

# %%
#Tim tri tuyet doi so x
x=float(input("x= "))
if x<0:
    ttd=-x
else:
    ttd=x
print("|%.2f|=%.2f"%(x,ttd))

# %%
#Tinh cuoc taxi
loaiXe=int(input("Loai xe (4 hoac 7) cho: "))
if loaiXe not in [4,7]:
    print ("Loai xe khong hop le")
else:
    kmDi=float(input("So km di chuyen = "))
    if kmDi<0:
        print("Quang duong khong hop le")
    else:
        thoiGianCho=float(input("Thoi gian cho (phut) = "))
        if thoiGianCho<0:
            print("Thoi gian khong hop le")
        else:
        #Tinh tien cho
            tienCho=0
            if thoiGianCho>5:
                tienCho=750*(thoiGianCho-5)
        #Tien cuoc di chuyen
            #Cac muc don gia
            if loaiXe==4:
                if kmDi<=0.8:
                    cuocVanChuyen=11000
                elif kmDi<=31:
                    cuocVanChuyen=11000+15300*(kmDi-0.8)
                else:
                    cuocVanChuyen=11000+15300*31+12100*(kmDi-31)
            else:                
                if kmDi<=0.8:
                    cuocVanChuyen=12000
                elif kmDi<=31:
                    cuocVanChuyen=12000+16100*(kmDi-0.8)
                else:
                    cuocVanChuyen=12000+16100*31+13800*(kmDi-31)
            tienCuoc=tienCho+cuocVanChuyen
            print("Tien cho = %.2f"%(tienCho))
            print("Cuoc di chuyen la= %.2f"%(cuocVanChuyen))
            print("Tong tien cuoc = %.2f"%(tienCuoc))

# %%
#Tinh tien dien sinh hoat ho gia dinh
soDien=float(input("So dien su dung: "))
if soDien<0:
    print("So dien khong hop le")
else:
    if soDien<=50:
        tienDien=1678*soDien
    elif soDien<=100:
        tienDien=1678*50+1734*(soDien-50)
    elif soDien<=200:
        tienDien=1678*50+1734*50+2014*(soDien-100)
    elif soDien<=300:
        tienDien=1678*50+1734*50+2014*100+2536*(soDien-200)
    elif soDien<=400:
        tienDien=1678*50+1734*50+2014*100+2536*100+2834*(soDien-300)
    else:
        tienDien=1678*50+1734*50+2014*100+2536*100+2834*100+2927*(soDien-400)
    print("So tien dien su dung la: %.2f"%(tienDien))

# %%
loaiPhong=int(input("Nhap ma loai phong:\n\t1/ Standard\n\t2/ Superior Garden View\n\t3/ Superior Ocean View\n\t4/ Garden View Bungalow\n\t5/ Pool Vie Bungalow\n\t6/ Family Room\n\t7/ Beach Front Bungalow\n\t8/ VIP sea view\n"))
if loaiPhong<1 or loaiPhong>8:
    print("Loai phong khong hop le")
else:
    soDem=int(input("Nhap so dem luu tru: "))
    if soDem<0:
        print("So dem khong hop le")
    else:
        if loaiPhong ==1:
            donGia=1260000
        elif loaiPhong==2:
            donGia=1550000
        elif loaiPhong==3:
            donGia=1830000
        elif loaiPhong==4:
            donGia=1830000
        elif loaiPhong==5:
            donGia=2120000
        elif loaiPhong==6:
            donGia=2120000
        elif loaiPhong==7:
            donGia=2540000
        else:
            donGia=4800000
        if sodem ==1:
            tienPhong=donGia
        elif:
# Out:
#   File "<ipython-input-1-0274bcdeedb2>", line 23
#     elif:
#         ^
# SyntaxError: invalid syntax

# %%
n = int(input().strip())
check = {True: "Not Weird", False: "Weird"}

print(check[
        n%2==0 and (
            n in range(2,6) or 
            n > 20)
    ])
# Out:
# 8
# Weird
